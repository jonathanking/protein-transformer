# %% [markdown]
# #  Tuesday, April 16th 2016
# This script will investigate what happened to previous runs of transformer models
# whose loss stagnated around `3.4` DRMSD.

# %%
import torch

# %%
model1 = "0325_lr:-2_warmup:500_clip:1_dwordvec:512"
model_paths = "../checkpoints/"
model1path = model_paths + model1 + "_best.chkpt"

# %%
m1 = torch.load(model1path)

# %%
m1
# Out:
# {'model': OrderedDict([('encoder.position_enc.weight',
#                tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#                          0.0000e+00,  0.0000e+00],
#                        [ 8.4147e-01,  5.4030e-01,  8.0196e-01,  ...,  1.0000e+00,
#                          1.0746e-04,  1.0000e+00],
#                        [ 9.0930e-01, -4.1615e-01,  9.5814e-01,  ...,  1.0000e+00,
#                          2.1492e-04,  1.0000e+00],
#                        ...,
#                        [-1.4991e-01, -9.8870e-01,  6.3100e-01,  ...,  9.9907e-01,
#                          4.0180e-02,  9.9919e-01],
#                        [-9.1296e-01, -4.0805e-01, -2.4520e-01,  ...,  9.9906e-01,
#                          4.0287e-02,  9.9919e-01],
#                        [-8.3664e-01,  5.4775e-01, -9.2396e-01,  ...,  9.9906e-01,
#                          4.0394e-02,  9.9918e-01]], device='cuda:0')),
#               ('encoder.layer_stack.0.slf_attn.w_qs.weight',
# ...

# %%
# !python ../scripts/load_predict.py
# Out:
# Traceback (most recent call last):
#   File "../scripts/load_predict.py", line 2, in <module>
#     import torch
# ImportError: No module named torch
